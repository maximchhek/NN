# %%
import os, random
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import random_split
from torchvision import transforms
from torchsummary import summary
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
max_in_class = 200
train_part = 0.5
noise = 0.1
batch_size = 30

epochs = 30
initial_lr = 0.0001

device = "cpu"

# %%
class CSVDataset(Dataset):
    def __init__(self, dataframe):
        self.data = dataframe.reset_index(drop=True)
        self.X = self.data.iloc[:, :-1].values
        self.y = self.data.iloc[:, -1].values

        self.X = torch.tensor(self.X, dtype=torch.float32)
        self.y = torch.tensor(self.y, dtype=torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# Загрузка данных
df = pd.read_csv("email_phishing_data.csv")

# Перемешиваем
df = shuffle(df, random_state=42)

# Разделяем по меткам
df_0 = df[df.iloc[:, -1] == 0].reset_index(drop=True)
df_1 = df[df.iloc[:, -1] == 1].reset_index(drop=True)

# Выбираем по 3000 с каждой меткой для тренировочной выборки
train_0 = df_0.iloc[:3000]
train_1 = df_1.iloc[:3000]

train_df = pd.concat([train_0, train_1])
train_df = shuffle(train_df, random_state=42)

# Остатки (после первых 3000)
remaining_0 = df_0.iloc[3000:]
remaining_1 = df_1.iloc[3000:]

# Для теста: минимум 2000 с меткой 1, остальное — с меткой 0
test_1 = remaining_1.iloc[:2000]
needed_0 = 6000 - len(test_1)
test_0 = remaining_0.iloc[:needed_0]

# Объединяем и перемешиваем
test_df = pd.concat([test_0, test_1])
test_df = shuffle(test_df, random_state=42)

train_dataset = CSVDataset(train_df)
test_dataset = CSVDataset(test_df)

train_dataloader = DataLoader(train_dataset, batch_size= batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=True)
print(len(train_dataloader.dataset), len(test_dataloader.dataset))

count_total = 0
count_train = 0
count_test = 0
eq = 1

# Во всём датасете
for i in range(len(dataset)):
    if dataset.y[i] == eq:
        count_total += 1

# В тренировочном подмножестве
for i in range(len(train_dataset)):
    if train_dataset.y[i] == eq:
        count_train += 1

# В тестовом подмножестве
for i in range(len(test_dataset)):
    if test_dataset.y[i] == eq:
        count_test += 1

print(f"Всего с меткой {eq}: {count_total}")
print(f"В train: {count_train}")
print(f"В test: {count_test}")

print(dataset.X)
# Out:
# 6000 6000
# Всего с меткой 1: 6949
# В train: 3000
# В test: 2000
# tensor([[140.,  94.,  52.,  ...,   0.,   0.,   0.],
#         [  5.,   5.,   1.,  ...,   0.,   0.,   0.],
#         [ 34.,  32.,  15.,  ...,   0.,   0.,   0.],
#         ...,
#         [ 61.,  46.,  11.,  ...,   0.,   3.,   0.],
#         [213., 136.,  89.,  ...,   0.,  18.,   0.],
#         [ 26.,  24.,   3.,  ...,   0.,   2.,   0.]])

# %%
tens_1 = torch.Tensor([[1]]*batch_size)

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(8, 64)
        self.drop = nn.Dropout(0.05)
        self.fc2 = nn.Linear(64, 32)
        self.drop = nn.Dropout(0.05)
        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.softmax(self.fc3(x), dim = 1)
        return x

# %%
model = SimpleNN()
#summary(model, (1, 28, 28), batch_size, device = device)
print(model)
# Out:
# SimpleNN(
#   (fc1): Linear(in_features=8, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
#   (drop): Dropout(p=0.05, inplace=False)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=initial_lr)
loss_fn = nn.CrossEntropyLoss()

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device).float(), y.to(device)

        # Compute prediction error
        #print(X, data_prep(X))
        pred = model(X)
        loss = loss_fn(pred, y)

        train_loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    if batch % 100 == 0:
        loss, current = loss.item(), (batch + 1) * len(X)
        print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss /= num_batches
    correct /= size

    return correct, train_loss

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device).float(), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

    return correct, test_loss

# %%
history = {
    'train_loss':[],
    'train_accuracy':[],
    'val_loss':[],
    'val_accuracy':[],
    'test_loss':[],
    'test_accuracy':[]
}

for t in range(epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {t+1}\n-------------------------------")
    #if(t % 2 == 0):
    #    initial_lr /= 2
    #    optimizer = torch.optim.Adam(model.parameters(), lr=initial_lr)
    acc, loss = train(train_dataloader, model, loss_fn, optimizer)
    history['train_accuracy'].append(acc)
    history['train_loss'].append(loss)
    acc, loss = test(test_dataloader, model, loss_fn)
    history['val_accuracy'].append(acc)
    history['val_loss'].append(loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 40.8%, Avg loss: 0.733495
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 50.0%, Avg loss: 0.664687
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.623638
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 59.3%, Avg loss: 0.642506
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 57.8%, Avg loss: 0.657457
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 63.9%, Avg loss: 0.626799
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.603465
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.617358
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 71.3%, Avg loss: 0.590115
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 55.5%, Avg loss: 0.675306
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 68.2%, Avg loss: 0.607778
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 68.2%, Avg loss: 0.605773
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 69.4%, Avg loss: 0.601573
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 62.1%, Avg loss: 0.660327
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 69.1%, Avg loss: 0.593555
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 66.9%, Avg loss: 0.608068
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 70.7%, Avg loss: 0.585802
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 69.3%, Avg loss: 0.594225
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 68.3%, Avg loss: 0.608835
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.551659
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.548336
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 73.6%, Avg loss: 0.552127
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.571677
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 56.0%, Avg loss: 0.816236
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.546511
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 61.4%, Avg loss: 0.670119
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.561778
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.669303
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 67.4%, Avg loss: 0.614755
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.651448
#
# Done!

# %%
epochs_range = range(epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history['train_accuracy'], label='Training Accuracy', color='red')
plt.plot(epochs_range, history['val_accuracy'], label='Validation Accuracy', color='blue')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history['train_loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history['val_loss'], label='Validation Loss', color='blue')
plt.legend(loc='lower left')
plt.title('Training and Validation Loss')
plt.grid()
plt.show()

# %%
model.eval()
test_dataloader
predictions = torch.LongTensor().to(device)
cmt = torch.zeros(2, 2, dtype=torch.int32)#Матрица ошибок
with torch.no_grad():
    for X, y in test_dataloader:
        X, y = X.to(device).float(), y.to(device)
        preds = model(X.to(device))
        predictions = preds.argmax(dim=1)
        cmt[y, predictions] += 1

# %%
pd.set_option('display.max_columns', 2)
pd.DataFrame(cmt.reshape(2, 2))#строка истинное значение, столбец предсказанное
# Out:
#       0     1
# 0  2201  1799
# 1   320  1680
