# %%
import os, random
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from torchvision import transforms
from torchsummary import summary
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split

import qiskit
from qiskit.circuit.library import RealAmplitudes, NLocal, ZZFeatureMap
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister, Parameter, ParameterVector
from qiskit_machine_learning.connectors import TorchConnector
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
import pylatexenc

# %%
max_in_class = 200
train_part = 0.5
noise = 0.1
batch_size = 30
reps = 1
num_qubit = 1

epochs = 200
initial_lr = 0.01

device = "cpu"

# %%
data = []
labels = []

def label_with_noise(label = 0, noise = 0):
    if(random.random() < noise):
        labels.append(1-label)
    else:
        labels.append(label)

n_samples = max_in_class * 2

for i in range(n_samples):
    if i < n_samples / 2:
        radius = random.uniform(3, 5)
        angle = random.uniform(0, 2 * np.pi)
        x = radius * np.cos(angle)
        y = radius * np.sin(angle)
        data.append([x, y])
        label_with_noise(0, noise)
    else:
        radius = random.uniform(0, 2)
        angle = random.uniform(0, 2 * np.pi)
        x = radius * np.cos(angle)
        y = radius * np.sin(angle)
        data.append([x, y])
        label_with_noise(1, noise)
data = np.array(data, dtype=np.float32)

x, y = zip(*data)

plt.scatter(x, y,
            c = labels,
            cmap = mcolors.ListedColormap(["b", "orange"]))

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.data = torch.tensor(data)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

dataset = MyDataset()
train_data, test_data = train_test_split(dataset, train_size=train_part, random_state=0)
train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
print(len(train_dataloader.dataset), len(test_dataloader.dataset))

#for batch in dataloader:
#    print("Batch Data:", batch[0])  
#    print("Batch Labels:", batch[1])
# Out:
# 200 200

# %%
class InitialStateQC:
    def __init__(self, n_qubits):
        self._circuit = qiskit.QuantumCircuit(n_qubits)
        params = ParameterVector('φ', n_qubits)
        
        for i in range(n_qubits):
            self._circuit.rx(np.pi/2 + params[i], i)#


class MyQuantumCircuit:
    def __init__(self, n_qubits, reps = 2):
        self._circuit = qiskit.QuantumCircuit(n_qubits)
        params = ParameterVector('Ψ', n_qubits*reps*2)#*2
        
        for i in range(n_qubits):
            for r in range(reps):
                self._circuit.ry(params[r*i+r], i)
                self._circuit.rz(params[r*i+r + n_qubits*reps], i)

def create_qnn(num_qubit = 2, reps = 3):
    feature_map = InitialStateQC(num_qubit)._circuit
    ansatz = MyQuantumCircuit(num_qubit, reps = reps)._circuit
    qc = QuantumCircuit(num_qubit)
    qc.compose(feature_map, inplace=True)
    qc.compose(ansatz, inplace=True)

    qnn = SamplerQNN(#SamplerQNN
        circuit = qc,
        sampler = None,
        input_params=feature_map.parameters,
        weight_params=ansatz.parameters,
        input_gradients=True
    )
    return qnn


qnn = create_qnn(num_qubit, reps)
# Out:
# C:\Users\maxsl\AppData\Local\Temp\ipykernel_21144\423785393.py:27: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = SamplerQNN(#SamplerQNN

# %%
qnn.circuit.draw("mpl")
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 qnn.circuit.draw("mpl")
#
# File D:\anaconda\Lib\site-packages\qiskit\circuit\quantumcircuit.py:3428, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    3425 # pylint: disable=cyclic-import
#    3426 from qiskit.visualization import circuit_drawer
# -> 3428 return circuit_drawer(
#    3429     self,
#    3430     scale=scale,
#    3431     filename=filename,
#    3432     style=style,
#    3433     output=output,
#    3434     interactive=interactive,
#    3435     plot_barriers=plot_barriers,
#    3436     reverse_bits=reverse_bits,
#    3437     justify=justify,
#    3438     vertical_compression=vertical_compression,
#    3439     idle_wires=idle_wires,
#    3440     with_layout=with_layout,
#    3441     fold=fold,
#    3442     ax=ax,
#    3443     initial_state=initial_state,
#    3444     cregbundle=cregbundle,
#    3445     wire_order=wire_order,
#    3446     expr_len=expr_len,
#    3447 )
#
# File D:\anaconda\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:332, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     317     return _generate_latex_source(
#     318         circuit,
#     319         filename=filename,
#    (...)
#     329         wire_order=complete_wire_order,
#     330     )
#     331 elif output == "mpl":
# --> 332     image = _matplotlib_circuit_drawer(
#     333         circuit,
#     334         scale=scale,
#     335         filename=filename,
#     336         style=style,
#     337         plot_barriers=plot_barriers,
#     338         reverse_bits=reverse_bits,
#     339         justify=justify,
#     340         idle_wires=idle_wires,
#     341         with_layout=with_layout,
#     342         fold=fold,
#     343         ax=ax,
#     344         initial_state=initial_state,
#     345         cregbundle=cregbundle,
#     346         wire_order=complete_wire_order,
#     347         expr_len=expr_len,
#     348     )
#     349 else:
#     350     raise VisualizationError(
#     351         f"Invalid output type {output} selected. The only valid choices "
#     352         "are text, latex, latex_source, and mpl"
#     353     )
#
# File D:\anaconda\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:712, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     709 if fold is None:
#     710     fold = 25
# --> 712 qcd = _matplotlib.MatplotlibDrawer(
#     713     qubits,
#     714     clbits,
#     715     nodes,
#     716     circuit,
#     717     scale=scale,
#     718     style=style,
#     719     reverse_bits=reverse_bits,
#     720     plot_barriers=plot_barriers,
#     721     fold=fold,
#     722     ax=ax,
#     723     initial_state=initial_state,
#     724     cregbundle=cregbundle,
#     725     with_layout=with_layout,
#     726     expr_len=expr_len,
#     727 )
#     728 return qcd.draw(filename)
#
# File D:\anaconda\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File D:\anaconda\Lib\site-packages\qiskit\utils\lazy_tester.py:41, in _RequireNow.__call__(self, *_args, **_kwargs)
#      40 def __call__(self, *_args, **_kwargs):
# ---> 41     self._tester.require_now(self._feature)
#
# File D:\anaconda\Lib\site-packages\qiskit\utils\lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# --> 221 raise MissingOptionalLibraryError(
#     222     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     223 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %%
tens_1 = torch.Tensor([[1]]*batch_size)

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.qnn = TorchConnector(qnn)

    def forward(self, x):
        x = self.qnn(x)
        return x

# %%
model = SimpleNN()
#summary(model, (2,1), batch_size, device = device)
print(model)
# Out:
# SimpleNN(
#   (qnn): TorchConnector()
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=initial_lr)
loss_fn = nn.CrossEntropyLoss()

# %%
def data_prep(X):
    data_X = []
    for i in range(len(X)):
        data_X.append([np.sqrt((X[i][0])**2 + (X[i][1])**2)])
    return torch.tensor(data_X).to(device)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(data_prep(X))
        loss = loss_fn(pred, y)

        train_loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    if batch % 100 == 0:
        loss, current = loss.item(), (batch + 1) * len(X)
        print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss /= num_batches
    correct /= size

    return correct, train_loss

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(data_prep(X))
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

    return correct, test_loss

# %%
history = {
    'train_loss':[],
    'train_accuracy':[],
    'val_loss':[],
    'val_accuracy':[],
    'test_loss':[],
    'test_accuracy':[]
}

for t in range(epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    print(f"Epoch {t+1}\n-------------------------------")
    acc, loss = train(train_dataloader, model, loss_fn, optimizer)
    history['train_accuracy'].append(acc)
    history['train_loss'].append(loss)
    acc, loss = test(test_dataloader, model, loss_fn)
    history['val_accuracy'].append(acc)
    history['val_loss'].append(loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.977618
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.978857
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.977752
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.978292
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.978255
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.979733
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.983879
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.972584
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.972155
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.971549
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.931684
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.847919
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 17.0%, Avg loss: 0.746074
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.658930
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.600995
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.569259
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.554929
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.540645
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533394
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529051
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535967
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531931
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532262
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530732
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529976
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531912
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527248
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.526937
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527920
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530579
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531317
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529856
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532947
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531743
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529750
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529727
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529501
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532763
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531139
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.526095
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527810
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530761
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533640
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533533
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531371
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535639
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531096
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527548
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533345
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529539
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533320
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529317
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531439
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527765
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527585
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529447
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529023
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.526152
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527646
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532414
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532462
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532608
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527508
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535433
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528837
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530508
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529506
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531004
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531404
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530466
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531778
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528707
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528510
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529659
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528806
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531259
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533134
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531743
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527708
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529939
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529480
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528857
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528929
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532759
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529490
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531916
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530234
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530438
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528439
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528338
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535967
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528832
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532303
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528814
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532556
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528718
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532388
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.526069
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527455
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529687
#
# Epoch 101
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534705
#
# Epoch 102
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529229
#
# Epoch 103
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531000
#
# Epoch 104
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529796
#
# Epoch 105
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529284
#
# Epoch 106
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531515
#
# Epoch 107
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535618
#
# Epoch 108
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531486
#
# Epoch 109
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527772
#
# Epoch 110
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.538302
#
# Epoch 111
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529137
#
# Epoch 112
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534065
#
# Epoch 113
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532271
#
# Epoch 114
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532802
#
# Epoch 115
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527621
#
# Epoch 116
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532735
#
# Epoch 117
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531913
#
# Epoch 118
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533858
#
# Epoch 119
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.536392
#
# Epoch 120
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529663
#
# Epoch 121
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527732
#
# Epoch 122
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532233
#
# Epoch 123
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534558
#
# Epoch 124
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532950
#
# Epoch 125
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528549
#
# Epoch 126
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530733
#
# Epoch 127
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530682
#
# Epoch 128
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527852
#
# Epoch 129
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532331
#
# Epoch 130
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530287
#
# Epoch 131
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535011
#
# Epoch 132
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533759
#
# Epoch 133
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529345
#
# Epoch 134
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.525326
#
# Epoch 135
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530906
#
# Epoch 136
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535221
#
# Epoch 137
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.540447
#
# Epoch 138
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534392
#
# Epoch 139
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529317
#
# Epoch 140
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.537631
#
# Epoch 141
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532075
#
# Epoch 142
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531968
#
# Epoch 143
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527118
#
# Epoch 144
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529313
#
# Epoch 145
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530932
#
# Epoch 146
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530652
#
# Epoch 147
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.525155
#
# Epoch 148
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531707
#
# Epoch 149
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534169
#
# Epoch 150
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530312
#
# Epoch 151
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529824
#
# Epoch 152
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532100
#
# Epoch 153
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532494
#
# Epoch 154
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530853
#
# Epoch 155
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531287
#
# Epoch 156
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.534944
#
# Epoch 157
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528935
#
# Epoch 158
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532077
#
# Epoch 159
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530020
#
# Epoch 160
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531676
#
# Epoch 161
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528912
#
# Epoch 162
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529769
#
# Epoch 163
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528754
#
# Epoch 164
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530580
#
# Epoch 165
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528105
#
# Epoch 166
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531212
#
# Epoch 167
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530028
#
# Epoch 168
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533265
#
# Epoch 169
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528689
#
# Epoch 170
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.526186
#
# Epoch 171
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528309
#
# Epoch 172
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530089
#
# Epoch 173
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530795
#
# Epoch 174
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533553
#
# Epoch 175
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529176
#
# Epoch 176
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530427
#
# Epoch 177
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.536965
#
# Epoch 178
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530178
#
# Epoch 179
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529319
#
# Epoch 180
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529300
#
# Epoch 181
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530004
#
# Epoch 182
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.531345
#
# Epoch 183
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528301
#
# Epoch 184
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529729
#
# Epoch 185
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528650
#
# Epoch 186
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530114
#
# Epoch 187
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528214
#
# Epoch 188
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528423
#
# Epoch 189
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.528837
#
# Epoch 190
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533496
#
# Epoch 191
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529720
#
# Epoch 192
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.529969
#
# Epoch 193
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.536944
#
# Epoch 194
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527075
#
# Epoch 195
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533851
#
# Epoch 196
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.527250
#
# Epoch 197
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.533603
#
# Epoch 198
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532154
#
# Epoch 199
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.532179
#
# Epoch 200
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.530342
#
# Done!

# %%
epochs_range = range(epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history['train_accuracy'], label='Training Accuracy', color='red')
plt.plot(epochs_range, history['val_accuracy'], label='Validation Accuracy', color='blue')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history['train_loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history['val_loss'], label='Validation Loss', color='blue')
plt.legend(loc='lower left')
plt.title('Training and Validation Loss')
plt.grid()
plt.show()

# %%
xy, l = zip(*train_dataloader.dataset)
x, y = zip(*xy)

plt.scatter(x, y,
            c = l,
            cmap = mcolors.ListedColormap(["b", "orange"]))

# %%
pred = model(data_prep(xy))
plt.scatter(x, y,
            c = pred.argmax(1),
            cmap = mcolors.ListedColormap(["b", "orange"]))

# %%
xy, l = zip(*test_dataloader.dataset)
x, y = zip(*xy)

plt.scatter(x, y,
            c = l,
            cmap = mcolors.ListedColormap(["b", "orange"]))

# %%
pred = model(data_prep(xy))
plt.scatter(x, y,
            c = pred.argmax(1),
            cmap = mcolors.ListedColormap(["b", "orange"]))

# %%
print(model.state_dict())
# Out:
# OrderedDict({'qnn.weight': tensor([-5.5058e-17, -4.7775e-01]), 'qnn._weights': tensor([-5.5058e-17, -4.7775e-01])})
